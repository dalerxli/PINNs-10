# %%
import IPython.display as ipd
import matplotlib.pyplot as plt
from scipy.io.wavfile import read, write

fs, data = read("Data/aa_DR1_MCPM0_sa1_float.wav")
fs, data2 = read("Data/formant.wav")
fs, data3 = read("Data/result_corpus.wav")
fs, data4 = read("Data/result_formant.wav")
# Out:
# /home/acc19ao/.conda/envs/tensorflow-gpu/lib/python3.6/site-packages/ipykernel/__main__.py:5: WavFileWarning: Chunk (non-data) not understood, skipping it.

# %%
ipd.Audio(data, rate=16000, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data2, rate=16000, normalize=True)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generate by aa_DR1_MCPM0_sa1_float (Corpus voice)
ipd.Audio(data3, rate=16000, normalize=True)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generate by periodic wave (Formant frequency)
ipd.Audio(data4, rate=16000, normalize=True)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
